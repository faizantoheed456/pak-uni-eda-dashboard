# %%
#Loading and inspection

# %%
import pandas as pd
import numpy as np

# %%
def loading_and_inspection(uni_data):
    # 1. First 10 rows from data 
    print('The first 10 rows from dataset:')
    display(uni_data.head(10))
    print("-" * 50)
    
    # 2. The shape of dataset
    print(f"Number of rows from dataset: {uni_data.shape[0]}.")
    print(f"Number of columns from dataset: {uni_data.shape[1]}.")
    print("-" * 50)
    
    # 3. All the columns with dtype
    dtype_df = pd.DataFrame(uni_data.dtypes, columns=['dtypes']).reset_index()
    print('Columns with their datatypes:')
    display(dtype_df)
    print("-" * 50)
    
    # 4. Concise summary with .info() 
    print("Here is the concise summary of our universities dataset:")
    uni_data.info()
    print("-" * 50)
    
    # 5. Statistics summary with .describe()
    print("Here is the summary of universities dataset:")
    display(uni_data.describe())
    print("-" * 50)
    
    # 6. Mean of total_enrollment
    print(f"The mean of total enrollment of students all over universities of Pakistan is: {uni_data['Total_Enrollment'].mean():.2f}.")
    print("-" * 50)
    
    # 7. Last 15 rows of dataset
    print("The last 15 rows of dataset:")
    display(uni_data.tail(15))
    print("-" * 50)
    
    # 8. Column names in a list
    uni_cols = uni_data.columns.tolist()
    print("Column names:", uni_cols)
    print("-" * 50)
    
    # 9. 10 random rows from the data
    print("10 random rows from the data:")
    display(uni_data.sample(10, random_state=42))
    print("-" * 50)
    
    # 10. Extract numeric vs non-numeric cols count
    numeric_cols = uni_data.select_dtypes(include=['int64', 'float64']).shape[1]
    object_cols = uni_data.select_dtypes(include=['object']).shape[1]
    print(f"Numeric columns: {numeric_cols}, Non-numeric columns: {object_cols}")
    print("-" * 50)
    
    # 11. Enlisting all the columns with null values
    null_cols = uni_data.columns[uni_data.isna().any()].tolist()
    print("Columns with null values:", null_cols)
    print("-" * 50)
    
    # 12. Memory usage of universities dataset in MB
    uni_mem = uni_data.memory_usage(deep=True).sum() / (1024 ** 2)
    print(f"Memory usage of university dataset: {uni_mem:.2f} MB")
    print("-" * 50)
    
    # 13. Most unique column in universities dataset
    most_unique_col = uni_data.nunique().sort_values(ascending=False).index[0]
    print(f"The column with the most unique values in dataset is: '{most_unique_col}'")
    print("-" * 50)
    
    # 14. First 3 rows and last three columns
    print("First 3 rows and last 3 columns:")
    display(uni_data.iloc[:3, -3:])
    print("-" * 50)
    
    # 15. Range of dataset rows
    uni_data_range = uni_data.index
    uni_data_index_dtype = uni_data_range.dtype
    print(f'Dataframe range: {uni_data_range}, Index Type: {uni_data_index_dtype}')

# %%
uni_data = pd.read_csv('pakistan_universities_dataset.csv')

# %%
loading_and_inspection(uni_data)
# Out:
# The first 10 rows from dataset:
#        UNI_ID                                   UNI_Name    Type Province  \
# 0  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 1  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 2  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 3  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 4  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 5  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 6  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 7  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 8  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
# 9  PK-AJK-002  Mirpur University of Science & Technology  Public      AJK
#
#      City  Established_Year  HEC_Ranking HEC_Category         Department_Name  \
# 0  Mirpur              2012          NaN           W1       Civil Engineering
# 1  Mirpur              2012          NaN           W1       Civil Engineering
# 2  Mirpur              2012          NaN           W1       Civil Engineering
# 3  Mirpur              2012          NaN           W1       Civil Engineering
# 4  Mirpur              2012          NaN           W1        Computer Science
# 5  Mirpur              2012          NaN           W1        Computer Science
# 6  Mirpur              2012          NaN           W1        Computer Science
# 7  Mirpur              2012          NaN           W1        Computer Science
# 8  Mirpur              2012          NaN           W1  Electrical Engineering
# 9  Mirpur              2012          NaN           W1  Electrical Engineering
#
#   Department_Category  ...  Dropout_Rate_Pct  Avg_Student_Background  \
# 0                STEM  ...               3.0       Mixed Urban-Rural
# 1                STEM  ...              17.6            Mostly Rural
# 2                STEM  ...               9.4       Mixed Urban-Rural
# 3                STEM  ...               3.5            Mostly Rural
# 4                STEM  ...              17.7       Mixed Urban-Rural
# 5                STEM  ...              12.3            Mostly Urban
# 6                STEM  ...               4.7            Mostly Rural
# 7                STEM  ...               8.7            Mostly Urban
# 8                STEM  ...               1.8            Mostly Urban
# 9                STEM  ...               5.2       Mixed Urban-Rural
#
#    Fee_Per_Semester_PKR  Lab_Count  Industry_Tie_Ups  Entry_Test_Required  \
# 0               24613.0        NaN              16.0                  Yes
# 1               12937.0       17.0               8.0                  Yes
# 2               25953.0        5.0              18.0                  Yes
# 3                   NaN        NaN               NaN                  Yes
# 4               12686.0        6.0               NaN                  Yes
# 5                   NaN       10.0               NaN                  Yes
# 6               25185.0       15.0              23.0                  Yes
# 7               39700.0        6.0               8.0                  Yes
# 8                   NaN        1.0              17.0                  Yes
# 9                9444.0       15.0               4.0                  Yes
#
#    Entry_Test_Type  Entry_Test_Tier  Entry_Test_Passing_Criteria  \
# 0  MUST Entry Test             Easy              45% / 100 marks
# 1  MUST Entry Test             Easy              45% / 100 marks
# 2  MUST Entry Test             Easy              45% / 100 marks
# 3  MUST Entry Test             Easy              45% / 100 marks
# 4  MUST Entry Test             Easy              45% / 100 marks
# 5  MUST Entry Test             Easy              45% / 100 marks
# 6  MUST Entry Test             Easy              45% / 100 marks
# 7  MUST Entry Test             Easy              45% / 100 marks
# 8  MUST Entry Test             Easy              45% / 100 marks
# 9  MUST Entry Test             Easy              45% / 100 marks
#
#    No_of_Buildings
# 0              NaN
# 1             10.0
# 2              9.0
# 3             12.0
# 4              NaN
# 5              8.0
# 6             12.0
# 7             12.0
# 8             12.0
# 9             11.0
#
# [10 rows x 34 columns]
# --------------------------------------------------
# Number of rows from dataset: 2584.
# Number of columns from dataset: 34.
# --------------------------------------------------
# Columns with their datatypes:
#                           index   dtypes
# 0                        UNI_ID   object
# 1                      UNI_Name   object
# 2                          Type   object
# 3                      Province   object
# 4                          City   object
# 5              Established_Year    int64
# 6                   HEC_Ranking  float64
# 7                  HEC_Category   object
# 8               Department_Name   object
# 9           Department_Category   object
# 10                         Year    int64
# 11             Total_Enrollment    int64
# 12              Male_Enrollment    int64
# 13            Female_Enrollment    int64
# 14                Faculty_Count    int64
# 15        Student_Faculty_Ratio  float64
# 16                 PhD_Students  float64
# 17            MS_MPhil_Students  float64
# 18                  BS_Students  float64
# 19         Scholarship_Students  float64
# 20       International_Students  float64
# 21    Research_Papers_Published  float64
# 22                     Avg_CGPA  float64
# 23         Employment_Ratio_Pct  float64
# 24             Dropout_Rate_Pct  float64
# 25       Avg_Student_Background   object
# 26         Fee_Per_Semester_PKR  float64
# 27                    Lab_Count  float64
# 28             Industry_Tie_Ups  float64
# 29          Entry_Test_Required   object
# 30              Entry_Test_Type   object
# 31              Entry_Test_Tier   object
# 32  Entry_Test_Passing_Criteria   object
# 33              No_of_Buildings  float64
# --------------------------------------------------
# Here is the concise summary of our universities dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2584 entries, 0 to 2583
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   UNI_ID                       2584 non-null   object
#  1   UNI_Name                     2584 non-null   object
#  2   Type                         2584 non-null   object
#  3   Province                     2584 non-null   object
#  4   City                         2584 non-null   object
#  5   Established_Year             2584 non-null   int64
#  6   HEC_Ranking                  2236 non-null   float64
#  7   HEC_Category                 2584 non-null   object
#  8   Department_Name              2584 non-null   object
#  9   Department_Category          2584 non-null   object
#  10  Year                         2584 non-null   int64
#  11  Total_Enrollment             2584 non-null   int64
#  12  Male_Enrollment              2584 non-null   int64
#  13  Female_Enrollment            2584 non-null   int64
#  14  Faculty_Count                2584 non-null   int64
#  15  Student_Faculty_Ratio        2584 non-null   float64
#  16  PhD_Students                 2120 non-null   float64
#  17  MS_MPhil_Students            2322 non-null   float64
#  18  BS_Students                  1903 non-null   float64
#  19  Scholarship_Students         2158 non-null   float64
#  20  International_Students       2053 non-null   float64
#  21  Research_Papers_Published    2275 non-null   float64
#  22  Avg_CGPA                     2242 non-null   float64
#  23  Employment_Ratio_Pct         2584 non-null   float64
#  24  Dropout_Rate_Pct             2209 non-null   float64
#  25  Avg_Student_Background       2347 non-null   object
#  26  Fee_Per_Semester_PKR         2353 non-null   float64
#  27  Lab_Count                    2190 non-null   float64
#  28  Industry_Tie_Ups             2048 non-null   float64
#  29  Entry_Test_Required          2584 non-null   object
#  30  Entry_Test_Type              2584 non-null   object
#  31  Entry_Test_Tier              2532 non-null   object
#  32  Entry_Test_Passing_Criteria  2532 non-null   object
#  33  No_of_Buildings              2440 non-null   float64
# dtypes: float64(15), int64(6), object(13)
# memory usage: 686.5+ KB
# --------------------------------------------------
# Here is the summary of universities dataset:
#        Established_Year  HEC_Ranking        Year  Total_Enrollment  \
# count       2584.000000  2236.000000  2584.00000       2584.000000
# mean        1980.965944    27.926655  2023.50000        808.919505
# std           35.866904    17.776439     1.11825        772.888471
# min         1860.000000     1.000000  2022.00000         48.000000
# 25%         1970.000000    11.000000  2022.75000        272.750000
# 50%         1998.000000    28.000000  2023.50000        506.000000
# 75%         2002.000000    44.000000  2024.25000       1034.500000
# max         2019.000000    60.000000  2025.00000       4079.000000
#
#        Male_Enrollment  Female_Enrollment  Faculty_Count  \
# count      2584.000000        2584.000000    2584.000000
# mean        445.412539         363.506966      28.659830
# std         442.923834         360.918456      28.064234
# min          20.000000          17.000000       5.000000
# 25%         147.000000         119.000000       9.000000
# 50%         276.000000         231.500000      18.000000
# 75%         580.250000         467.500000      37.000000
# max        2775.000000        2302.000000     172.000000
#
#        Student_Faculty_Ratio  PhD_Students  MS_MPhil_Students  ...  \
# count            2584.000000   2120.000000        2322.000000  ...
# mean               28.615983     32.855660          78.263997  ...
# std                 4.820937     41.463083          96.862760  ...
# min                 9.600000      0.000000           0.000000  ...
# 25%                25.300000      7.000000          17.000000  ...
# 50%                28.700000     17.000000          43.500000  ...
# 75%                32.300000     41.000000          99.000000  ...
# max                41.600000    282.000000         714.000000  ...
#
#        Scholarship_Students  International_Students  \
# count           2158.000000             2053.000000
# mean              84.009731               30.265465
# std              100.308451               17.459426
# min                5.000000                0.000000
# 25%               21.000000               15.000000
# 50%               47.000000               30.000000
# 75%              104.000000               45.000000
# max              747.000000               60.000000
#
#        Research_Papers_Published     Avg_CGPA  Employment_Ratio_Pct  \
# count                2275.000000  2242.000000           2584.000000
# mean                   42.243956     3.148608             64.801509
# std                    22.760266     0.312249             13.574135
# min                     3.000000     2.600000             32.100000
# 25%                    22.000000     2.880000             53.875000
# 50%                    43.000000     3.150000             65.900000
# 75%                    62.000000     3.410000             75.500000
# max                    80.000000     3.700000             97.000000
#
#        Dropout_Rate_Pct  Fee_Per_Semester_PKR    Lab_Count  Industry_Tie_Ups  \
# count       2209.000000           2353.000000  2190.000000       2048.000000
# mean           9.829425          38760.630684    10.404110         17.049316
# std            4.788452          30410.250857     5.820969         10.268216
# min            1.500000           8005.000000     1.000000          0.000000
# 25%            5.700000          18903.000000     5.000000          8.000000
# 50%            9.800000          30383.000000    10.000000         17.000000
# 75%           14.000000          41826.000000    15.000000         26.000000
# max           18.000000         175697.000000    20.000000         35.000000
#
#        No_of_Buildings
# count      2440.000000
# mean         18.522541
# std          13.238853
# min           3.000000
# 25%          11.000000
# 50%          15.000000
# 75%          21.000000
# max         100.000000
#
# [8 rows x 21 columns]
# --------------------------------------------------
# The mean of total enrollment of students all over universities of Pakistan is: 808.92.
# --------------------------------------------------
# The last 15 rows of dataset:
#           UNI_ID                      UNI_Name    Type Province      City  \
# 2569  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2570  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2571  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2572  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2573  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2574  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2575  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2576  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2577  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2578  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2579  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2580  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2581  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2582  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
# 2583  PK-SIN-013  University of Sindh Jamshoro  Public    Sindh  Jamshoro
#
#       Established_Year  HEC_Ranking HEC_Category        Department_Name  \
# 2569              1947         26.0           W2              Education
# 2570              1947         26.0           W2              Education
# 2571              1947         26.0           W2              Education
# 2572              1947         26.0           W2  Environmental Science
# 2573              1947         26.0           W2  Environmental Science
# 2574              1947         26.0           W2  Environmental Science
# 2575              1947         26.0           W2  Environmental Science
# 2576              1947         26.0           W2     Mass Communication
# 2577              1947         26.0           W2     Mass Communication
# 2578              1947         26.0           W2     Mass Communication
# 2579              1947         26.0           W2     Mass Communication
# 2580              1947         26.0           W2      Political Science
# 2581              1947         26.0           W2      Political Science
# 2582              1947         26.0           W2      Political Science
# 2583              1947         26.0           W2      Political Science
#
#          Department_Category  ...  Dropout_Rate_Pct  Avg_Student_Background  \
# 2569  Arts & Social Sciences  ...              12.9            Mostly Urban
# 2570  Arts & Social Sciences  ...               3.8            Mostly Urban
# 2571  Arts & Social Sciences  ...               5.6            Mostly Urban
# 2572                    STEM  ...               6.3            Mostly Rural
# 2573                    STEM  ...              14.1       Mixed Urban-Rural
# 2574                    STEM  ...               6.1                     NaN
# 2575                    STEM  ...               7.4                     NaN
# 2576  Arts & Social Sciences  ...              11.5            Mostly Urban
# 2577  Arts & Social Sciences  ...               1.8       Mixed Urban-Rural
# 2578  Arts & Social Sciences  ...               8.8            Mostly Rural
# 2579  Arts & Social Sciences  ...               NaN            Mostly Rural
# 2580  Arts & Social Sciences  ...               4.4            Mostly Rural
# 2581  Arts & Social Sciences  ...               5.1            Mostly Rural
# 2582  Arts & Social Sciences  ...               3.9       Mixed Urban-Rural
# 2583  Arts & Social Sciences  ...              16.7            Mostly Rural
#
#       Fee_Per_Semester_PKR  Lab_Count  Industry_Tie_Ups  Entry_Test_Required  \
# 2569               31148.0        5.0              27.0                  Yes
# 2570               43465.0        9.0              33.0                  Yes
# 2571               18135.0       14.0              27.0                  Yes
# 2572                   NaN       16.0               NaN                  Yes
# 2573                   NaN        7.0              30.0                  Yes
# 2574               43241.0        NaN              32.0                  Yes
# 2575               13535.0       14.0               NaN                  Yes
# 2576               44061.0       14.0               6.0                  Yes
# 2577               10435.0       12.0               NaN                  Yes
# 2578                   NaN        NaN              12.0                  Yes
# 2579               26705.0       15.0              34.0                  Yes
# 2580               24306.0       12.0               5.0                  Yes
# 2581               39328.0       12.0              17.0                  Yes
# 2582               31761.0       10.0               NaN                  Yes
# 2583               18903.0        NaN               4.0                  Yes
#
#         Entry_Test_Type  Entry_Test_Tier  Entry_Test_Passing_Criteria  \
# 2569  USINDH Entry Test             Easy              45% / 100 marks
# 2570  USINDH Entry Test             Easy              45% / 100 marks
# 2571  USINDH Entry Test             Easy              45% / 100 marks
# 2572  USINDH Entry Test             Easy              45% / 100 marks
# 2573  USINDH Entry Test             Easy              45% / 100 marks
# 2574  USINDH Entry Test             Easy              45% / 100 marks
# 2575  USINDH Entry Test             Easy              45% / 100 marks
# 2576  USINDH Entry Test             Easy              45% / 100 marks
# 2577  USINDH Entry Test             Easy              45% / 100 marks
# 2578  USINDH Entry Test             Easy              45% / 100 marks
# 2579  USINDH Entry Test             Easy              45% / 100 marks
# 2580  USINDH Entry Test             Easy              45% / 100 marks
# 2581  USINDH Entry Test             Easy              45% / 100 marks
# 2582  USINDH Entry Test             Easy              45% / 100 marks
# 2583  USINDH Entry Test             Easy              45% / 100 marks
#
#       No_of_Buildings
# 2569             38.0
# 2570             41.0
# 2571             45.0
# 2572             38.0
# 2573             39.0
# 2574             41.0
# 2575             48.0
# 2576             43.0
# 2577             38.0
# 2578             46.0
# 2579             42.0
# 2580             42.0
# 2581             38.0
# 2582             41.0
# 2583             41.0
#
# [15 rows x 34 columns]
# --------------------------------------------------
# Column names: ['UNI_ID', 'UNI_Name', 'Type', 'Province', 'City', 'Established_Year', 'HEC_Ranking', 'HEC_Category', 'Department_Name', 'Department_Category', 'Year', 'Total_Enrollment', 'Male_Enrollment', 'Female_Enrollment', 'Faculty_Count', 'Student_Faculty_Ratio', 'PhD_Students', 'MS_MPhil_Students', 'BS_Students', 'Scholarship_Students', 'International_Students', 'Research_Papers_Published', 'Avg_CGPA', 'Employment_Ratio_Pct', 'Dropout_Rate_Pct', 'Avg_Student_Background', 'Fee_Per_Semester_PKR', 'Lab_Count', 'Industry_Tie_Ups', 'Entry_Test_Required', 'Entry_Test_Type', 'Entry_Test_Tier', 'Entry_Test_Passing_Criteria', 'No_of_Buildings']
# --------------------------------------------------
# 10 random rows from the data:
#           UNI_ID                                     UNI_Name    Type  \
# 2099  PK-PUN-001                     University of the Punjab  Public
# 435   PK-FED-006                     Air University Islamabad  Public
# 1729  PK-PUN-027  PMAS Arid Agriculture University Rawalpindi  Public
# 321   PK-BAL-006                         University of Turbat  Public
# 2582  PK-SIN-013                 University of Sindh Jamshoro  Public
# 254   PK-BAL-008                         University of Gwadar  Public
# 56    PK-AJK-001           University of Azad Jammu & Kashmir  Public
# 2018  PK-PUN-026                       University of Sargodha  Public
# 393    PK-GB-002               University of Baltistan Skardu  Public
# 2494  PK-SIN-014        Sindh Agriculture University Tandojam  Public
#
#               Province          City  Established_Year  HEC_Ranking  \
# 2099            Punjab        Lahore              1882          7.0
# 435          Islamabad     Islamabad              2002         18.0
# 1729            Punjab    Rawalpindi              1970         29.0
# 321        Balochistan        Turbat              2012          NaN
# 2582             Sindh      Jamshoro              1947         26.0
# 254        Balochistan        Gwadar              2016          NaN
# 56                 AJK  Muzaffarabad              1980         43.0
# 2018            Punjab      Sargodha              2002         44.0
# 393   Gilgit-Baltistan        Skardu              2016          NaN
# 2494             Sindh      Tandojam              1977          3.0
#
#      HEC_Category           Department_Name     Department_Category  ...  \
# 2099           W4                       Law  Arts & Social Sciences  ...
# 435            W3    Information Technology                    STEM  ...
# 1729           W2  Agricultural Engineering                    STEM  ...
# 321            W1         Civil Engineering                    STEM  ...
# 2582           W2         Political Science  Arts & Social Sciences  ...
# 254            W1         Civil Engineering                    STEM  ...
# 56             W1                      Urdu  Arts & Social Sciences  ...
# 2018           W1          Computer Science                    STEM  ...
# 393            W1         Civil Engineering                    STEM  ...
# 2494           W3  Agricultural Engineering                    STEM  ...
#
#       Dropout_Rate_Pct  Avg_Student_Background  Fee_Per_Semester_PKR  \
# 2099              12.9       Mixed Urban-Rural               25039.0
# 435                6.0            Mostly Rural               32684.0
# 1729               NaN            Mostly Urban               34560.0
# 321               15.3       Mixed Urban-Rural               28769.0
# 2582               3.9       Mixed Urban-Rural               31761.0
# 254               17.7            Mostly Rural               33752.0
# 56                 NaN       Mixed Urban-Rural               16892.0
# 2018               NaN            Mostly Rural               10708.0
# 393                8.1            Mostly Rural               12643.0
# 2494               2.8            Mostly Urban               40661.0
#
#       Lab_Count  Industry_Tie_Ups  Entry_Test_Required    Entry_Test_Type  \
# 2099       15.0              17.0                  Yes      PU Entry Test
# 435         3.0              24.0                  Yes      AU Entry Test
# 1729       15.0               0.0                  Yes    UAAR Entry Test
# 321        10.0              11.0                  Yes     UoT Entry Test
# 2582       10.0               NaN                  Yes  USINDH Entry Test
# 254         1.0              28.0                  Yes     UoG Entry Test
# 56         13.0               NaN                  Yes    UAJK Entry Test
# 2018        3.0               NaN                  Yes     UOS Entry Test
# 393         NaN              11.0                  Yes     UBS Entry Test
# 2494        NaN              31.0                  Yes     SAU Entry Test
#
#       Entry_Test_Tier  Entry_Test_Passing_Criteria  No_of_Buildings
# 2099           Medium              50% / 100 marks             91.0
# 435            Medium              50% / 100 marks             17.0
# 1729             Easy              45% / 100 marks             23.0
# 321              Easy              40% / 100 marks              5.0
# 2582             Easy              45% / 100 marks             41.0
# 254              Easy              40% / 100 marks              7.0
# 56               Easy              45% / 100 marks             19.0
# 2018             Easy              45% / 100 marks             21.0
# 393              Easy              40% / 100 marks              4.0
# 2494             Easy              45% / 100 marks             25.0
#
# [10 rows x 34 columns]
# --------------------------------------------------
# Numeric columns: 21, Non-numeric columns: 13
# --------------------------------------------------
# Columns with null values: ['HEC_Ranking', 'PhD_Students', 'MS_MPhil_Students', 'BS_Students', 'Scholarship_Students', 'International_Students', 'Research_Papers_Published', 'Avg_CGPA', 'Dropout_Rate_Pct', 'Avg_Student_Background', 'Fee_Per_Semester_PKR', 'Lab_Count', 'Industry_Tie_Ups', 'Entry_Test_Tier', 'Entry_Test_Passing_Criteria', 'No_of_Buildings']
# --------------------------------------------------
# Memory usage of university dataset: 2.33 MB
# --------------------------------------------------
# The column with the most unique values in dataset is: 'Fee_Per_Semester_PKR'
# --------------------------------------------------
# First 3 rows and last 3 columns:
#   Entry_Test_Tier Entry_Test_Passing_Criteria  No_of_Buildings
# 0            Easy             45% / 100 marks              NaN
# 1            Easy             45% / 100 marks             10.0
# 2            Easy             45% / 100 marks              9.0
# --------------------------------------------------
# Dataframe range: RangeIndex(start=0, stop=2584, step=1), Index Type: int64

# %%
def data_cleaning_pipeline(uni_data):
    """
    Advanced Data Cleaning Pipeline for Pakistan Universities Dataset.
    Logs all imputations via flag columns, resolves regional urban biases, 
    cleans categorical quirks, and optimizes memory formats.
    """
    # Create a deep copy to preserve the raw input data
    df_clean = uni_data.copy()
    
    # 1. Handle disguised missing values
    df_clean.replace(['N/A', 'na', 'unknown', ''], pd.NA, inplace=True)
    
    # List of all columns we expect to impute/fill
    impute_target_cols = [
        'HEC_Ranking', 'Industry_Tie_Ups', 'Fee_Per_Semester_PKR', 'Scholarship_Students', 
        'International_Students', 'Avg_CGPA', 'No_of_Buildings', 'Lab_Count', 
        'Dropout_Rate_Pct', 'Research_Papers_Published', 'BS_Students', 
        'PhD_Students', 'MS_MPhil_Students', 'Avg_Student_Background',
        'Entry_Test_Tier', 'Entry_Test_Passing_Criteria'
    ]
    
    # Create boolean flag columns tracking missingness before cleaning
    for col in impute_target_cols:
        if col in df_clean.columns:
            df_clean[f'{col}_is_imputed'] = df_clean[col].isna()
    
    # 2. Revert HEC_Ranking cleanly (Preserve real ranks, map missing/0 to 'None')
    df_clean['HEC_Ranking'] = df_clean['HEC_Ranking'].astype(str).str.replace(r'\.0$', '', regex=True).str.strip()
    df_clean['HEC_Ranking'] = pd.to_numeric(df_clean['HEC_Ranking'], errors='coerce').fillna(0).astype(int)
    df_clean['HEC_Ranking'] = df_clean['HEC_Ranking'].astype(str).replace({'0': 'None'})
    
    # 3. Handle Numerical Columns via University-Specific Medians (Fallback to Global Median)
    numeric_impute_cols = [
        'Industry_Tie_Ups', 'Fee_Per_Semester_PKR', 'Scholarship_Students', 
        'International_Students', 'Avg_CGPA', 'No_of_Buildings', 
        'Lab_Count', 'Dropout_Rate_Pct', 'Research_Papers_Published'
    ]
    df_clean[numeric_impute_cols] = df_clean.groupby('UNI_ID')[numeric_impute_cols].transform(lambda x: x.fillna(x.median()))
    df_clean[numeric_impute_cols] = df_clean[numeric_impute_cols].fillna(df_clean[numeric_impute_cols].median())
    
    # 4. Handle Student Level Relationships Logically (BS, PhD, MS/MPhil)
    calculated_bs = df_clean['Total_Enrollment'] - (df_clean['MS_MPhil_Students'].fillna(0) + df_clean['PhD_Students'].fillna(0))
    df_clean['BS_Students'] = df_clean['BS_Students'].fillna(calculated_bs)
    
    calculated_phd = df_clean['Total_Enrollment'] - (df_clean['BS_Students'].fillna(0) + df_clean['MS_MPhil_Students'].fillna(0))
    df_clean['PhD_Students'] = df_clean['PhD_Students'].fillna(calculated_phd)
    
    calculated_ms_mphil = df_clean['Total_Enrollment'] - (df_clean['BS_Students'].fillna(0) + df_clean['PhD_Students'].fillna(0))
    df_clean['MS_MPhil_Students'] = df_clean['MS_MPhil_Students'].fillna(calculated_ms_mphil)
    
    # 5. Handle Categorical Columns via Regional Mode (Mitigates Urban Bias)
    province_modes = df_clean.groupby('Province')['Avg_Student_Background'].transform(
        lambda x: x.fillna(x.mode()[0] if not x.mode().empty else df_clean['Avg_Student_Background'].mode()[0])
    )
    df_clean['Avg_Student_Background'] = df_clean['Avg_Student_Background'].fillna(province_modes)
    
    # Clean entry test details based on structural filter requirements
    test_mask = df_clean['Entry_Test_Required'].str.strip().str.lower() != 'no'
    for col in ['Entry_Test_Tier', 'Entry_Test_Passing_Criteria']:
        mode_val = df_clean.loc[test_mask, col].mode()[0]
        df_clean.loc[test_mask & df_clean[col].isna(), col] = mode_val
        df_clean.loc[~test_mask & df_clean[col].isna(), col] = 'None'
        
    # 6. Clean Text Whitespaces
    string_cols = df_clean.select_dtypes(include=['object']).columns
    for col in string_cols:
        df_clean[col] = df_clean[col].str.strip()
        
    # 7. Optimize Numeric Types (Downcasting Memory)
    for col in df_clean.select_dtypes(include=['int64', 'float64']).columns:
        df_clean[col] = pd.to_numeric(df_clean[col], downcast='integer' if df_clean[col].dtype == 'int64' else 'float')
        
    # 8. Convert Text Columns to Categorical Data Type
    categorical_cols = [
        'Type', 'Province', 'City', 'HEC_Category', 'HEC_Ranking', 'Department_Name', 
        'Department_Category', 'Avg_Student_Background', 'Entry_Test_Type', 
        'Entry_Test_Tier', 'Entry_Test_Required', 'Entry_Test_Passing_Criteria'
    ]
    for col in categorical_cols:
        df_clean[col] = df_clean[col].astype('category')
        
    # Pipeline execution audit report
    print("Production Data Cleaning Pipeline executed successfully!")
    print(f"Remaining Structural Missing Values: {df_clean[uni_data.columns].isnull().sum().sum()}")
    print(f"Imputation Logs Generated: {len(impute_target_cols)} flag columns created.")
    print(f"Final Dataframe Shape: {df_clean.shape[0]} rows, {df_clean.shape[1]} columns")
    
    return df_clean

# %%
# Run the pipeline on your raw dataset
cleaned_uni_data = data_cleaning_pipeline(uni_data)
cleaned_uni_data.to_csv('pakistan_universities_dataset_clean.csv', index=False)
# Take a look at your optimized concise summary
cleaned_uni_data.info()
# Out:
# Production Data Cleaning Pipeline executed successfully!
# Remaining Structural Missing Values: 0
# Imputation Logs Generated: 16 flag columns created.
# Final Dataframe Shape: 2584 rows, 50 columns
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2584 entries, 0 to 2583
# Data columns (total 50 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   UNI_ID                                  2584 non-null   object
#  1   UNI_Name                                2584 non-null   object
#  2   Type                                    2584 non-null   category
#  3   Province                                2584 non-null   category
#  4   City                                    2584 non-null   category
#  5   Established_Year                        2584 non-null   int16
#  6   HEC_Ranking                             2584 non-null   category
#  7   HEC_Category                            2584 non-null   category
#  8   Department_Name                         2584 non-null   category
#  9   Department_Category                     2584 non-null   category
#  10  Year                                    2584 non-null   int16
#  11  Total_Enrollment                        2584 non-null   int16
#  12  Male_Enrollment                         2584 non-null   int16
#  13  Female_Enrollment                       2584 non-null   int16
#  14  Faculty_Count                           2584 non-null   int16
#  15  Student_Faculty_Ratio                   2584 non-null   float32
#  16  PhD_Students                            2584 non-null   float32
#  17  MS_MPhil_Students                       2584 non-null   float32
#  18  BS_Students                             2584 non-null   float32
#  19  Scholarship_Students                    2584 non-null   float32
#  20  International_Students                  2584 non-null   float32
#  21  Research_Papers_Published               2584 non-null   float32
#  22  Avg_CGPA                                2584 non-null   float32
#  23  Employment_Ratio_Pct                    2584 non-null   float32
#  24  Dropout_Rate_Pct                        2584 non-null   float32
#  25  Avg_Student_Background                  2584 non-null   category
#  26  Fee_Per_Semester_PKR                    2584 non-null   float32
#  27  Lab_Count                               2584 non-null   float32
#  28  Industry_Tie_Ups                        2584 non-null   float32
#  29  Entry_Test_Required                     2584 non-null   category
#  30  Entry_Test_Type                         2584 non-null   category
#  31  Entry_Test_Tier                         2584 non-null   category
#  32  Entry_Test_Passing_Criteria             2584 non-null   category
#  33  No_of_Buildings                         2584 non-null   float32
#  34  HEC_Ranking_is_imputed                  2584 non-null   bool
#  35  Industry_Tie_Ups_is_imputed             2584 non-null   bool
#  36  Fee_Per_Semester_PKR_is_imputed         2584 non-null   bool
#  37  Scholarship_Students_is_imputed         2584 non-null   bool
#  38  International_Students_is_imputed       2584 non-null   bool
#  39  Avg_CGPA_is_imputed                     2584 non-null   bool
#  40  No_of_Buildings_is_imputed              2584 non-null   bool
#  41  Lab_Count_is_imputed                    2584 non-null   bool
#  42  Dropout_Rate_Pct_is_imputed             2584 non-null   bool
#  43  Research_Papers_Published_is_imputed    2584 non-null   bool
#  44  BS_Students_is_imputed                  2584 non-null   bool
#  45  PhD_Students_is_imputed                 2584 non-null   bool
#  46  MS_MPhil_Students_is_imputed            2584 non-null   bool
#  47  Avg_Student_Background_is_imputed       2584 non-null   bool
#  48  Entry_Test_Tier_is_imputed              2584 non-null   bool
#  49  Entry_Test_Passing_Criteria_is_imputed  2584 non-null   bool
# dtypes: bool(16), category(12), float32(14), int16(6), object(2)
# memory usage: 292.7+ KB

# %%
c_uni_data = cleaned_uni_data.copy()

# %%
def execution_analysis_pipeline(c_uni_data):
    """
    Executes the comprehensive 10-question EDA notebook analysis.
    Directly displays all cleaned and corrected summary outputs.
    """
    # Q1: Complete HEC category ranking
    print("=== Q1: HEC Category Ranking by Avg CGPA ===")
    q1_output = (
        c_uni_data.groupby('HEC_Category', observed=False)['Avg_CGPA']
        .mean()
        .sort_values(ascending=False)
    )
    display(q1_output)
    print("\n" + "="*50 + "\n")
    
    # Q2: Number of universities per Province
    print("=== Q2: Number of Universities by Province ===")
    q2_output = (
        c_uni_data.groupby('Province', observed=False)['UNI_Name']
        .nunique()
        .sort_values(ascending=False)
    )
    display(q2_output)
    print("\n" + "="*50 + "\n")
    
    # Q3: Research output by broad department category
    print("=== Q3: Total Research Papers by Department Category ===")
    q3_output = (
        c_uni_data.groupby('Department_Category', observed=False)['Research_Papers_Published']
        .sum()
        .sort_values(ascending=False)
    )
    display(q3_output)
    print("\n" + "="*50 + "\n")
    
    # Q4: Median semester fee by sector Type
    print("=== Q4: Median Fee Per Semester by University Type ===")
    q4_output = (
        c_uni_data.groupby('Type', observed=False)['Fee_Per_Semester_PKR']
        .median()
    )
    display(q4_output)
    print("\n" + "="*50 + "\n")
    
    # Q5: Top 5 cities by average Employment Ratio (with >= 3 universities)
    print("=== Q5: Top 5 Cities by Average Employment Ratio (Min 3 Unis) ===")
    city_counts = c_uni_data.groupby('City', observed=False)['UNI_Name'].nunique()
    eligible_cities = city_counts[city_counts >= 3].index
    q5_output = (
        c_uni_data[c_uni_data['City'].isin(eligible_cities)]
        .groupby('City', observed=False)['Employment_Ratio_Pct']
        .mean()
        .nlargest(5)
    )
    display(q5_output)
    print("\n" + "="*50 + "\n")
    
    # Q6: Dropout rates - Overall and Sector Breakdown
    print("=== Q6 (Part 1): Overall Average Dropout Rate by Province ===")
    q6_overall = (
        c_uni_data.groupby('Province', observed=True)['Dropout_Rate_Pct']
        .mean()
        .sort_values(ascending=False)
    )
    display(q6_overall)
    print("\n--- Q6 (Part 2): Breakdown by Province and Type ---")
    q6_breakdown = (
        c_uni_data.groupby(['Province', 'Type'], observed=True)['Dropout_Rate_Pct']
        .mean()
        .sort_values(ascending=False)
    )
    display(q6_breakdown)
    print("\n" + "="*50 + "\n")
    
    # Q7: Academic and market metrics across entry test difficulty tiers
    print("=== Q7: Metrics by Entry Test Tier ===")
    q7_output = (
        c_uni_data.groupby('Entry_Test_Tier', observed=False)[['Avg_CGPA', 'Employment_Ratio_Pct']]
        .mean()
    )
    display(q7_output)
    print("\n*Note: Clear positive correlation observed. Higher entrance difficulty links directly to stronger CGPAs and employment metrics.*")
    print("\n" + "="*50 + "\n")
    
    # Q8: High enrollment aggregate summary (>50k students)
    print("=== Q8: Summary Table (Enrollments > 50,000) ===")
    summary_table = (
        c_uni_data.groupby(['Province', 'Department_Category'], observed=True)
        .agg(
            Total_Enrollment=('Total_Enrollment', 'sum'),
            Avg_Student_Faculty_Ratio=('Student_Faculty_Ratio', 'mean'),
            Number_of_Departments=('Department_Name', 'nunique') # Unique check fixed
        )
    )
    q8_output = summary_table[summary_table['Total_Enrollment'] > 50000]
    display(q8_output)
    print("\n" + "="*50 + "\n")
    
    # Q9: Count unique universities exceeding provincial female share baselines
    print("=== Q9: Universities Exceeding Provincial Female Share Baseline ===")
    uni_level = (
        c_uni_data.groupby(['Province', 'UNI_Name'], observed=True)
        .agg(Total_Female=('Female_Enrollment', 'sum'), Total_Students=('Total_Enrollment', 'sum'))
        .reset_index()
    )
    uni_level['Female_Share'] = uni_level['Total_Female'] / uni_level['Total_Students']
    uni_level['Provincial_Avg'] = uni_level.groupby('Province', observed=True)['Female_Share'].transform('mean')
    
    q9_output = (
        uni_level[uni_level['Female_Share'] > uni_level['Provincial_Avg']]
        .groupby('Province', observed=True)['UNI_Name']
        .nunique()
        .sort_values(ascending=False)
    )
    display(q9_output)
    print("\n" + "="*50 + "\n")
    
    # Q10: Top research category per year
    print("=== Q10: Top Department Category for Research Output Yearly ===")
    q10_output = (
        c_uni_data.groupby(['Year', 'Department_Category'], observed=True)['Research_Papers_Published']
        .mean()
        .reset_index()
        .sort_values('Research_Papers_Published', ascending=False)
        .drop_duplicates(subset=['Year'], keep='first')
        .sort_values('Year')
        .reset_index(drop=True)
    )
    display(q10_output)

# %%
# Execute the pipeline to print and display all 10 answers cleanly
execution_analysis_pipeline(c_uni_data)
# Out:
# === Q1: HEC Category Ranking by Avg CGPA ===
# HEC_Category
# W4    3.171169
# W2    3.152528
# W3    3.151596
# W1    3.138430
# Name: Avg_CGPA, dtype: float32
# ==================================================
#
# === Q2: Number of Universities by Province ===
# Province
# Punjab              30
# Sindh               18
# Islamabad           15
# KPK                 14
# Balochistan         10
# AJK                  2
# Gilgit-Baltistan     2
# Name: UNI_Name, dtype: int64
# ==================================================
#
# === Q3: Total Research Papers by Department Category ===
# Department_Category
# STEM                      70888.0
# Arts & Social Sciences    29485.0
# Business                   8819.0
# Name: Research_Papers_Published, dtype: float32
# ==================================================
#
# === Q4: Median Fee Per Semester by University Type ===
# Type
# Private    97808.0
# Public     26838.0
# Name: Fee_Per_Semester_PKR, dtype: float32
# ==================================================
#
# === Q5: Top 5 Cities by Average Employment Ratio (Min 3 Unis) ===
# City
# Jamshoro    72.716179
# Quetta      68.831253
# Lahore      65.868958
# Peshawar    65.688637
# Karachi     64.878349
# Name: Employment_Ratio_Pct, dtype: float32
# ==================================================
#
# === Q6 (Part 1): Overall Average Dropout Rate by Province ===
# Province
# KPK                 10.119307
# AJK                 10.075000
# Islamabad           10.074573
# Punjab               9.941019
# Gilgit-Baltistan     9.732142
# Sindh                9.490126
# Balochistan          9.216555
# Name: Dropout_Rate_Pct, dtype: float32
# --- Q6 (Part 2): Breakdown by Province and Type ---
# Province          Type
# Islamabad         Public     10.228385
# KPK               Public     10.179211
# AJK               Public     10.075000
# Punjab            Private    10.062712
#                   Public      9.892177
# Gilgit-Baltistan  Public      9.732142
# Sindh             Public      9.583928
# Islamabad         Private     9.371428
# Balochistan       Public      9.216555
# KPK               Private     9.170834
# Sindh             Private     9.052382
# Name: Dropout_Rate_Pct, dtype: float32
# ==================================================
#
# === Q7: Metrics by Entry Test Tier ===
#                  Avg_CGPA  Employment_Ratio_Pct
# Entry_Test_Tier
# Difficult        3.167500             72.463524
# Easy             3.146288             63.213188
# Medium           3.144235             62.723904
# None             3.107500             62.217308
# *Note: Clear positive correlation observed. Higher entrance difficulty links directly to stronger CGPAs and employment metrics.*
#
# ==================================================
#
# === Q8: Summary Table (Enrollments > 50,000) ===
#                                     Total_Enrollment  \
# Province    Department_Category
# Balochistan STEM                               63295
# Islamabad   Arts & Social Sciences            163639
#             STEM                              430424
# KPK         STEM                              144879
# Punjab      Arts & Social Sciences            189223
#             Business                          100769
#             STEM                              414609
# Sindh       Arts & Social Sciences            118572
#             STEM                              278595
#
#                                     Avg_Student_Faculty_Ratio  \
# Province    Department_Category
# Balochistan STEM                                    28.982000
# Islamabad   Arts & Social Sciences                  29.000736
#             STEM                                    29.057894
# KPK         STEM                                    28.209059
# Punjab      Arts & Social Sciences                  28.970371
#             Business                                27.960184
#             STEM                                    28.983599
# Sindh       Arts & Social Sciences                  28.018549
#             STEM                                    28.126602
#
#                                     Number_of_Departments
# Province    Department_Category
# Balochistan STEM                                       23
# Islamabad   Arts & Social Sciences                      9
#             STEM                                       15
# KPK         STEM                                       24
# Punjab      Arts & Social Sciences                     13
#             Business                                    6
#             STEM                                       29
# Sindh       Arts & Social Sciences                     13
#             STEM                                       26
# ==================================================
#
# === Q9: Universities Exceeding Provincial Female Share Baseline ===
# Province
# Punjab              18
# Islamabad            8
# Sindh                8
# KPK                  6
# Balochistan          5
# AJK                  1
# Gilgit-Baltistan     1
# Name: UNI_Name, dtype: int64
# ==================================================
#
# === Q10: Top Department Category for Research Output Yearly ===
#    Year     Department_Category  Research_Papers_Published
# 0  2022  Arts & Social Sciences                  43.340000
# 1  2023  Arts & Social Sciences                  41.205715
# 2  2024                    STEM                  43.906025
# 3  2025  Arts & Social Sciences                  43.077145

# %%
def run_feature_engineering_pipeline(df_path, output_path):
    """
    Consolidates all 10 feature engineering exercises into a single pipeline,
    executes them, and saves the enhanced dataset to a CSV file.
    """
    # Load the cleaned dataset
    df = pd.read_csv(df_path)
    
    print("--- Starting Feature Engineering Pipeline ---")

    # 1 & 2. Female Share Percentage & Binning
    df['Female_Share_Pct'] = (df['Female_Enrollment'] / df['Total_Enrollment'].replace(0, np.nan)).fillna(0) * 100
    df['Gender_Balance_Category'] = pd.cut(
        df['Female_Share_Pct'], 
        bins=[-1, 30, 60, 101], 
        labels=['Male Dominated', 'Balanced', 'Female Dominated']
    )
    print("Calculated Female Share and Gender Categories.")

    # 3. Annual Fee & Fee Bands
    df['Annual_Fee_PKR'] = df['Fee_Per_Semester_PKR'] * 2
    df['Fee_Band'] = pd.qcut(
        df['Annual_Fee_PKR'], 
        q=[0, 0.33, 0.66, 1.0], 
        labels=['Low', 'Mid', 'High']
    )
    print("Calculated Annual Fee and Percentile Fee Bands.")

    # 4. Research Productivity Per Faculty
    df['Research_Per_Faculty'] = (
        df['Research_Papers_Published'] / df['Faculty_Count'].replace(0, np.nan)
    ).fillna(0)
    print("Calculated Research Per Faculty.")

    # 5. Campus Density & Overcrowding Flag
    df['Campus_Density'] = (
        df['Total_Enrollment'] / df['No_of_Buildings'].replace(0, np.nan)
    ).fillna(0)
    national_median_density = df['Campus_Density'].median()
    df['Is_Overcrowded'] = (df['Campus_Density'] > (1.5 * national_median_density)).astype(int)
    print(f"Flagged Overcrowded Campuses (National Median Density Baseline: {national_median_density:.2f}).")

    # 6. Postgraduate Ratio & Research Focus Flag
    df['PG_Ratio'] = (
        ((df['MS_MPhil_Students'] + df['PhD_Students']) / df['Total_Enrollment'].replace(0, np.nan)) * 100
    ).fillna(0)
    median_research_per_faculty = df['Research_Per_Faculty'].median()
    df['Is_Research_Focused'] = (
        (df['PG_Ratio'] > 30) & (df['Research_Per_Faculty'] > median_research_per_faculty)
    ).astype(int)
    print("Calculated PG Ratio and Research Focus Flags.")

    # 7. Selectivity Score
    tier_mapping = {'Difficult': 3, 'Medium': 2, 'Easy': 1, 'None': 0}
    encoded_tier = df['Entry_Test_Tier'].astype(str).map(tier_mapping).fillna(0)
    cgpa_min, cgpa_max = df['Avg_CGPA'].min(), df['Avg_CGPA'].max()
    normalized_cgpa = (df['Avg_CGPA'] - cgpa_min) / (cgpa_max - cgpa_min) if (cgpa_max - cgpa_min) != 0 else 0
    df['Selectivity_Score'] = (0.5 * encoded_tier) + (0.5 * normalized_cgpa)
    print("Calculated Selectivity Score.")

    # 8. University Score Composite Ranking (Aggregated to University Level)
    metrics = ['Employment_Ratio_Pct', 'Research_Per_Faculty', 'Avg_CGPA', 'Industry_Tie_Ups']
    uni_means = df.groupby('UNI_ID')[metrics].transform('mean')
    
    norm_metrics = {}
    for col in metrics:
        c_min, c_max = uni_means[col].min(), uni_means[col].max()
        norm_metrics[col] = (uni_means[col] - c_min) / (c_max - c_min) if (c_max - c_min) != 0 else 0
        
    df['University_Score'] = (
        (0.35 * norm_metrics['Employment_Ratio_Pct']) +
        (0.25 * norm_metrics['Research_Per_Faculty']) +
        (0.25 * norm_metrics['Avg_CGPA']) +
        (0.15 * norm_metrics['Industry_Tie_Ups'])
    )
    print("Calculated Composite University Score.")

    # 9. Fee Value Score
    df['Fee_Value_Score'] = (df['Employment_Ratio_Pct'] / df['Annual_Fee_PKR']) * 100000
    print("Calculated Fee Value Score.")

    # 10. Peer CGPA Gap (Regional Tier Benchmarking)
    provincial_tier_mean = df.groupby(['Province', 'HEC_Category'], observed=False)['Avg_CGPA'].transform('mean')
    df['Peer_CGPA_Gap'] = df['Avg_CGPA'] - provincial_tier_mean
    print("Calculated Peer CGPA Gap Benchmark.")

    # 11. Risk Index Composite
    norm_dropout = (df['Dropout_Rate_Pct'] - df['Dropout_Rate_Pct'].min()) / (df['Dropout_Rate_Pct'].max() - df['Dropout_Rate_Pct'].min())
    norm_sfr = (df['Student_Faculty_Ratio'] - df['Student_Faculty_Ratio'].min()) / (df['Student_Faculty_Ratio'].max() - df['Student_Faculty_Ratio'].min())
    inverted_female = 1 - (df['Female_Share_Pct'] - df['Female_Share_Pct'].min()) / (df['Female_Share_Pct'].max() - df['Female_Share_Pct'].min())
    df['Risk_Index'] = (norm_dropout + norm_sfr + inverted_female) / 3
    print("Calculated Institutional Risk Index.")

    # Save to disk
    df.to_csv(output_path, index=False)
    print(f"Success! Engineered dataset saved with shape {df.shape} to: '{output_path}'")
    return df

# %%
enhanced_df = run_feature_engineering_pipeline(
    df_path='pakistan_universities_dataset_clean.csv',
    output_path='pakistan_universities_dataset_enhanced.csv'
)
# Out:
# --- Starting Feature Engineering Pipeline ---
# Calculated Female Share and Gender Categories.
# Calculated Annual Fee and Percentile Fee Bands.
# Calculated Research Per Faculty.
# Flagged Overcrowded Campuses (National Median Density Baseline: 34.47).
# Calculated PG Ratio and Research Focus Flags.
# Calculated Selectivity Score.
# Calculated Composite University Score.
# Calculated Fee Value Score.
# Calculated Peer CGPA Gap Benchmark.
# Calculated Institutional Risk Index.
# Success! Engineered dataset saved with shape (2584, 64) to: 'pakistan_universities_dataset_enhanced.csv'
